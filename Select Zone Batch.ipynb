# %%
solaSpec = {
    "type": "SOLA_TRAFFIC_ASSIGNMENT",
    "classes": [
        {
            "mode": "j",
            "demand": "mf121",
            "generalized_cost": None,
            "results": {
                "link_volumes": None,
                "turn_volumes": None,
                "od_travel_times": {
                    "shortest_paths": None
                }
            },
            "path_analyses": [
                {
                    "link_component": "@sel",
                    "path_to_od_composition": {
                        "multiply_path_proportions_by": {
                            "path_value": False,
                            "analyzed_demand": True
                        },
                        "considered_paths": "SELECTED"
                    },
                    "turn_component": None,
                    "analyzed_demand": None,
                    "results": {
                        "selected_turn_volumes": None,
                        "od_values":None,
                        "selected_link_volumes": "@volau1_nt"
                    },
                    "operator": ".max.",
                    "selection_threshold": {
                        "upper": 1,
                        "lower": 1
                    }
                }
            ]
        },
        {
            "mode": "J",
            "demand": "mf122",
            "generalized_cost": None,
            "results": {
                "link_volumes": None,
                "turn_volumes": None,
                "od_travel_times": {
                    "shortest_paths": None
                }
            },
            "path_analyses": [
                {
                    "link_component": "@sel",
                    "turn_component": None,
                    "operator": ".max.",
                    "selection_threshold": {
                        "lower": 1,
                        "upper": 1
                    },
                    "path_to_od_composition": {
                        "considered_paths": "SELECTED",
                        "multiply_path_proportions_by": {
                            "analyzed_demand": True,
                            "path_value": False
                        }
                    },
                    "analyzed_demand": None,
                    "results": {
                        "selected_link_volumes": "@volau1_toll",
                        "selected_turn_volumes": None,
                        "od_values":None
                    }
                }
            ]
        },
        {
            "mode": "j",
            "demand": "mf123",
            "generalized_cost": None,
            "results": {
                "link_volumes": None,
                "turn_volumes": None,
                "od_travel_times": {
                    "shortest_paths": None
                }
            },
            "path_analyses": [
                {
                    "link_component": "@sel",
                    "turn_component": None,
                    "operator": ".max.",
                    "selection_threshold": {
                        "lower": 1,
                        "upper": 1
                    },
                    "path_to_od_composition": {
                        "considered_paths": "SELECTED",
                        "multiply_path_proportions_by": {
                            "analyzed_demand": True,
                            "path_value": False
                        }
                    },
                    "analyzed_demand": None,
                    "results": {
                        "selected_link_volumes": "@volau2_nt_nh",
                        "selected_turn_volumes": None,
                        "od_values": None
                    }
                }
            ]
        },
        {
            "mode": "h",
            "demand": "mf124",
            "generalized_cost": None,
            "results": {
                "link_volumes": None,
                "turn_volumes": None,
                "od_travel_times": {
                    "shortest_paths": None
                }
            },
            "path_analyses": [
                {
                    "link_component": "@sel",
                    "path_to_od_composition": {
                        "considered_paths": "SELECTED",
                        "multiply_path_proportions_by": {
                            "analyzed_demand": True,
                            "path_value": False
                        }
                    },
                    "turn_component": None,
                    "results": {
                        "selected_turn_volumes": None,
                        "selected_link_volumes": "@volau2_nt_hov",
                        "od_values": None
                    },
                    "analyzed_demand": None,
                    "operator": ".max.",
                    "selection_threshold": {
                        "upper": 1,
                        "lower": 1
                    }
                }
            ]
        },
        {
            "mode": "J",
            "demand": "mf125",
            "generalized_cost": None,
            "results": {
                "link_volumes": None,
                "turn_volumes": None,
                "od_travel_times": {
                    "shortest_paths": None
                }
            },
            "path_analyses": [
                {
                    "link_component": "@sel",
                    "turn_component": None,
                    "operator": ".max.",
                    "selection_threshold": {
                        "lower": 1,
                        "upper": 1
                    },
                    "path_to_od_composition": {
                        "considered_paths": "SELECTED",
                        "multiply_path_proportions_by": {
                            "analyzed_demand": True,
                            "path_value": False
                        }
                    },
                    "analyzed_demand": None,
                    "results": {
                        "selected_link_volumes": "@volau2_toll_nh",
                        "selected_turn_volumes": None,
                        "od_values": None
                    }
                }
            ]
        },
        {
            "mode": "H",
            "demand": "mf126",
            "generalized_cost": None,
            "results": {
                "link_volumes": None,
                "turn_volumes": None,
                "od_travel_times": {
                    "shortest_paths": None
                }
            },
            "path_analyses": [
                {
                    "link_component": "@sel",
                    "path_to_od_composition": {
                        "considered_paths": "SELECTED",
                        "multiply_path_proportions_by": {
                            "analyzed_demand": True,
                            "path_value": False
                        }
                    },
                    "turn_component": None,
                    "results": {
                        "selected_turn_volumes": None,
                        "selected_link_volumes": "@volau2_toll_hov",
                        "od_values": None
                    },
                    "analyzed_demand": None,
                    "operator": ".max.",
                    "selection_threshold": {
                        "upper": 1,
                        "lower": 1
                    }
                }
            ]
        },
        {
            "mode": "j",
            "demand": "mf127",
            "generalized_cost": None,
            "results": {
                "link_volumes": None,
                "turn_volumes": None,
                "od_travel_times": {
                    "shortest_paths": None
                }
            },
            "path_analyses": [
                {
                    "link_component": "@sel",
                    "turn_component": None,
                    "operator": ".max.",
                    "selection_threshold": {
                        "lower": 1,
                        "upper": 1
                    },
                    "path_to_od_composition": {
                        "considered_paths": "SELECTED",
                        "multiply_path_proportions_by": {
                            "analyzed_demand": True,
                            "path_value": False
                        }
                    },
                    "analyzed_demand": None,
                    "results": {
                        "selected_link_volumes": "@volau3_nt_nh",
                        "selected_turn_volumes": None,
                        "od_values":None
                    }
                }
            ]
        },
        {
            "mode": "i",
            "demand": "mf128",
            "generalized_cost": None,
            "results": {
                "link_volumes": None,
                "turn_volumes": None,
                "od_travel_times": {
                    "shortest_paths": None
                }
            },
            "path_analyses": [
                {
                    "link_component": "@sel",
                    "path_to_od_composition": {
                        "multiply_path_proportions_by": {
                            "path_value": False,
                            "analyzed_demand": True
                        },
                        "considered_paths": "SELECTED"
                    },
                    "turn_component": None,
                    "results": {
                        "selected_turn_volumes": None,
                        "selected_link_volumes": "@volau3_nt_hov",
                        "od_values": None
                    },
                    "analyzed_demand": None,
                    "operator": ".max.",
                    "selection_threshold": {
                        "upper": 1,
                        "lower": 1
                    }
                }
            ]
        },
        {
            "mode": "J",
            "demand": "mf129",
            "generalized_cost": None,
            "results": {
                "link_volumes": None,
                "turn_volumes": None,
                "od_travel_times": {
                    "shortest_paths": None
                }
            },
            "path_analyses": [
                {
                    "link_component": "@sel",
                    "turn_component": None,
                    "operator": ".max.",
                    "selection_threshold": {
                        "lower": 1,
                        "upper": 1
                    },
                    "path_to_od_composition": {
                        "considered_paths": "SELECTED",
                        "multiply_path_proportions_by": {
                            "analyzed_demand": True,
                            "path_value": False
                        }
                    },
                    "analyzed_demand": None,
                    "results": {
                        "selected_link_volumes": "@volau3_toll_nh",
                        "selected_turn_volumes": None,
                        "od_values": None
                    }
                }
            ]
        },
        {
            "mode": "I",
            "demand": "mf130",
            "generalized_cost": None,
            "results": {
                "link_volumes": None,
                "turn_volumes": None,
                "od_travel_times": {
                    "shortest_paths": None
                }
            },
            "path_analyses": [
                {
                    "link_component": "@sel",
                    "path_to_od_composition": {
                        "multiply_path_proportions_by": {
                            "path_value": False,
                            "analyzed_demand": True
                        },
                        "considered_paths": "SELECTED"
                    },
                    "turn_component": None,
                    "results": {
                        "selected_turn_volumes": None,
                        "selected_link_volumes": "@volau3_toll_hov",
                        "od_values": None
                    },
                    "analyzed_demand": None,
                    "operator": ".max.",
                    "selection_threshold": {
                        "upper": 1,
                        "lower": 1
                    }
                }
            ]
        },
        {
            "mode": "d",
            "demand": "mf165",
            "generalized_cost": {
                "link_costs": "@toll_mtruck",
                "perception_factor": 0.015
            },
            "results": {
                "link_volumes": None,
                "turn_volumes": None,
                "od_travel_times": {
                    "shortest_paths": None
                }
            },
            "path_analyses": [
                {
                    "link_component": "@sel",
                    "path_to_od_composition": {
                        "multiply_path_proportions_by": {
                            "path_value": False,
                            "analyzed_demand": True
                        },
                        "considered_paths": "SELECTED"
                    },
                    "turn_component": None,
                    "results": {
                        "selected_turn_volumes": None,
                        "selected_link_volumes": "@volau_ltruck",
                        "od_values": None
                    },
                    "analyzed_demand": None,
                    "operator": ".max.",
                    "selection_threshold": {
                        "upper": 1,
                        "lower": 1
                    }
                }
            ]
        },
        {
            "mode": "e",
            "demand": "mf170",
            "generalized_cost": {
                "link_costs": "@toll_mtruck",
                "perception_factor": 0.003
            },
            "results": {
                "link_volumes": None,
                "turn_volumes": None,
                "od_travel_times": {
                    "shortest_paths": None
                }
            },
            "path_analyses": [
                {
                    "link_component": "@sel",
                    "path_to_od_composition": {
                        "multiply_path_proportions_by": {
                            "path_value": False,
                            "analyzed_demand": True
                        },
                        "considered_paths": "SELECTED"
                    },
                    "turn_component": None,
                    "results": {
                        "selected_turn_volumes": None,
                        "selected_link_volumes": "@volau_mtruck",
                        "od_values": None
                    },
                    "analyzed_demand": None,
                    "operator": ".max.",
                    "selection_threshold": {
                        "upper": 1,
                        "lower": 1
                    }
                }
            ]
        },
        {
            "mode": "f",
            "demand": "mf175",
            "generalized_cost": {
                "link_costs": "@toll_htruck",
                "perception_factor": 0.0024
            },
            "results": {
                "link_volumes": None,
                "turn_volumes": None,
                "od_travel_times": {
                    "shortest_paths": None
                }
            },
            "path_analyses": [
                {
                    "link_component": "@sel",
                    "path_to_od_composition": {
                        "multiply_path_proportions_by": {
                            "path_value": False,
                            "analyzed_demand": True
                        },
                        "considered_paths": "SELECTED"
                    },
                    "turn_component": None,
                    "results": {
                        "selected_turn_volumes": None,
                        "selected_link_volumes": "@volau_htruck",
                        "od_values": None
                    },
                    "analyzed_demand": None,
                    "operator": ".max.",
                    "selection_threshold": {
                        "upper": 1,
                        "lower": 1
                    }
                }
            ]
        }
    ],
    "performance_settings": {
        "number_of_processors": 8
    },
    "background_traffic": None,
    "stopping_criteria": {
        "max_iterations": 15,
        "relative_gap": 0.05,
        "best_relative_gap": 0,
        "normalized_gap": 0
    }
}

# %%
import inro.modeller as m
import os
import glob
import csv
import pandas as pd

mm = m.Modeller()
eb = m.Modeller().emmebank

#tools
import_matrices = mm.tool("tmg.input_output.import_binary_matrix")           
change_matrix = mm.tool("inro.emme.data.matrix.change_matrix_properties")
create_matrix =  mm.tool("inro.emme.data.matrix.create_matrix")
matrix_calculator = mm.tool("inro.emme.matrix_calculation.matrix_calculator")
matrix_transaction = mm.tool('inro.emme.data.matrix.matrix_transaction')
network_calculator = mm.tool("inro.emme.network_calculation.network_calculator")
selectLink = mm.tool("inro.emme.traffic_assignment.sola_traffic_assignment")
create_ea = mm.tool("inro.emme.data.extra_attribute.create_extra_attribute")
init_ea = mm.tool("inro.emme.data.extra_attribute.init_extra_attribute")

#HDR Scripts
common = mm.module('org.emme.common')
#moe = mm.module('org.emme.moe')

matrix_folder = r"\\tore-infs01\PWExternal\451010\281829_GGH\GGHM Runs\2041\MTO_2041_GGH_MTP_328_V105_CS222_20190522"

sc_am = eb.scenario(211)

# %%
networkCalcSpec = {
    "result": None,
    "expression": None,
    "aggregation": None,
    "selections": {
        "link": "all",
    },
    "type": "NETWORK_CALCULATION"
}

# %%
car_list ={
    "trips_am_peak_auto1_nt" :"mf121",
    "trips_am_peak_auto1_toll" :"mf122",
    "trips_am_peak_auto2_nt_hov" :"mf124",
    "trips_am_peak_auto2_nt_nh" :"mf123",
    "trips_am_peak_auto2_toll_hov" :"mf126",
    "trips_am_peak_auto2_toll_nh" :"mf125",
    "trips_am_peak_auto3_nt_hov" :"mf128",
    "trips_am_peak_auto3_nt_nh" :"mf127",
    "trips_am_peak_auto3_toll_hov" :"mf130",
    "trips_am_peak_auto3_toll_nh" :"mf129",}
truck_list ={
    "lt_truck_ampkhr": "mf165",
    "mt_truck_ampkhr": "mf170",
    "ht_truck_ampkhr": "mf175"}

# %%
for matrix_name in matrix_list.keys():
    #matrix_list[matrix_name] = eb.available_matrix_identifier('FULL')
    create_matrix(matrix_id = matrix_list[matrix_name],
                  matrix_name= matrix_name,
                  matrix_description = matrix_name)

# %%
common.import_matrices_from_directory(matrix_folder, car_list, ".mdf",sc_am)

# %%
common.import_matrices_from_directory(matrix_folder, truck_list, ".mdf",eb.scenario(116))

# %%
from copy import deepcopy

# %%
clearNetwork = deepcopy(networkCalcSpec)
clearNetwork["result"] = "@sel"
clearNetwork["expression"] = "0"
network_calculator(clearNetwork)
# Out:
# {'average': 0.0,
#  'expression_type': 'LINK',
#  'maximum': 0.0,
#  'maximum_at': {'i_node': 1001, 'j_node': 10000},
#  'minimum': 0.0,
#  'minimum_at': {'i_node': 1001, 'j_node': 10000},
#  'num_attributes_changed': 0,
#  'num_evaluations': 88664,
#  'num_results_obtained': 88664,
#  'result_type': 'LINK',
#  'sum': 0.0}

# %%
zones = pd.read_csv(r"C:\Users\BCRANE\Documents\Long List\SelectZone3.csv")

# %%
zones
# Out:
#                            Area  Att
# 0      Scarborough south of 401   56
# 1      Scarborough north of 401   57
# 2                Yonge-Eglinton   58
# 3                Yonge-Sheppard   59
# 4  Central Toronto south of 401   60
# 5  Central Toronto north of 401   61
# 6                      Sheridan   62
# 7                    Meadowvale   63
# 8                  Airport SKID   64

# %%
vol_eas = ["@volau1_nt","@volau1_toll","@volau2_nt_nh","@volau2_nt_hov","@volau2_toll_nh","@volau2_toll_hov","@volau3_nt_nh",
"@volau3_nt_hov","@volau3_toll_nh","@volau3_toll_hov","@volau_htruck","@volau_mtruck","@volau_ltruck"]

# %%
for index, row in zones.iterrows():
    network_calculator(clearNetwork)
    analysisID = row.Att
    tagNetwork = deepcopy(networkCalcSpec)
    tagNetwork["result"] = "@sel"
    tagNetwork["expression"] = "1"
    tagNetwork["selections"]["link"] = "@s_zone={}".format(row.Att)
    network_calculator(tagNetwork)
    tagNetwork["selections"]["link"] = "@s_zonej={}".format(row.Att)
    network_calculator(tagNetwork)
    
    for ea in vol_eas:
        init_ea(ea,0)
    
    print("starting ta for {}".format(row.Area))
    
    selectLink(solaSpec)
    
    create_ea("LINK","@selvolzone{}".format(analysisID), "Vol {}".format(row.Area), overwrite = True)
    
    saveVol = deepcopy(networkCalcSpec)
    saveVol["result"] = "@selvolzone{}".format(analysisID)
    saveVol["expression"] = "@volau1_nt+@volau1_toll+@volau2_nt_nh+@volau2_nt_hov+@volau2_toll_nh+@volau2_toll_hov+@volau3_nt_nh+\
@volau3_nt_hov+@volau3_toll_nh+@volau3_toll_hov+@volau_htruck+@volau_mtruck+@volau_ltruck"
    network_calculator(saveVol)

# %%
create_ea("LINK","@selvolzone{}".format(analysisID), "Vol {}".format(row.Area), overwrite = True)
saveVol = deepcopy(networkCalcSpec)
saveVol["result"] = "@selvolzone{}".format(analysisID)
saveVol["expression"] = "@volau1_nt+@volau1_toll+@volau2_nt_nh+@volau2_nt_hov+@volau2_toll_nh+@volau2_toll_hov+@volau3_nt_nh+\
@volau3_nt_hov+@volau3_toll_nh+@volau3_toll_hov+@volau_htruck+@volau_mtruck+@volau_ltruck"
network_calculator(saveVol)
# Out:
# {'average': 4.649385,
#  'expression_type': 'LINK',
#  'maximum': 1886.527344,
#  'maximum_at': {'i_node': 12172, 'j_node': 1528},
#  'minimum': 0.0,
#  'minimum_at': {'i_node': 1003, 'j_node': 12699},
#  'num_attributes_changed': 65151,
#  'num_evaluations': 88664,
#  'num_results_obtained': 88664,
#  'result_type': 'LINK',
#  'sum': 412233.0625}
