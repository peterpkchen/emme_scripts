# %%
solaSpec = {
    "type": "SOLA_TRAFFIC_ASSIGNMENT",
    "classes": [
        {
            "mode": "j",
            "demand": "mf121",
            "generalized_cost": None,
            "results": {
                "link_volumes": None,
                "turn_volumes": None,
                "od_travel_times": {
                    "shortest_paths": None
                }
            },
            "path_analyses": [
                {
                    "link_component": "@sel",
                    "path_to_od_composition": {
                        "multiply_path_proportions_by": {
                            "path_value": False,
                            "analyzed_demand": True
                        },
                        "considered_paths": "SELECTED"
                    },
                    "turn_component": None,
                    "analyzed_demand": None,
                    "results": {
                        "selected_turn_volumes": None,
                        "od_values":None,
                        "selected_link_volumes": "@volau1_nt"
                    },
                    "operator": ".max.",
                    "selection_threshold": {
                        "upper": 1,
                        "lower": 1
                    }
                }
            ]
        },
        {
            "mode": "J",
            "demand": "mf122",
            "generalized_cost": None,
            "results": {
                "link_volumes": None,
                "turn_volumes": None,
                "od_travel_times": {
                    "shortest_paths": None
                }
            },
            "path_analyses": [
                {
                    "link_component": "@sel",
                    "turn_component": None,
                    "operator": ".max.",
                    "selection_threshold": {
                        "lower": 1,
                        "upper": 1
                    },
                    "path_to_od_composition": {
                        "considered_paths": "SELECTED",
                        "multiply_path_proportions_by": {
                            "analyzed_demand": True,
                            "path_value": False
                        }
                    },
                    "analyzed_demand": None,
                    "results": {
                        "selected_link_volumes": "@volau1_toll",
                        "selected_turn_volumes": None,
                        "od_values":None
                    }
                }
            ]
        },
        {
            "mode": "j",
            "demand": "mf123",
            "generalized_cost": None,
            "results": {
                "link_volumes": None,
                "turn_volumes": None,
                "od_travel_times": {
                    "shortest_paths": None
                }
            },
            "path_analyses": [
                {
                    "link_component": "@sel",
                    "turn_component": None,
                    "operator": ".max.",
                    "selection_threshold": {
                        "lower": 1,
                        "upper": 1
                    },
                    "path_to_od_composition": {
                        "considered_paths": "SELECTED",
                        "multiply_path_proportions_by": {
                            "analyzed_demand": True,
                            "path_value": False
                        }
                    },
                    "analyzed_demand": None,
                    "results": {
                        "selected_link_volumes": "@volau2_nt_nh",
                        "selected_turn_volumes": None,
                        "od_values": None
                    }
                }
            ]
        },
        {
            "mode": "h",
            "demand": "mf124",
            "generalized_cost": None,
            "results": {
                "link_volumes": None,
                "turn_volumes": None,
                "od_travel_times": {
                    "shortest_paths": None
                }
            },
            "path_analyses": [
                {
                    "link_component": "@sel",
                    "path_to_od_composition": {
                        "considered_paths": "SELECTED",
                        "multiply_path_proportions_by": {
                            "analyzed_demand": True,
                            "path_value": False
                        }
                    },
                    "turn_component": None,
                    "results": {
                        "selected_turn_volumes": None,
                        "selected_link_volumes": "@volau2_nt_hov",
                        "od_values": None
                    },
                    "analyzed_demand": None,
                    "operator": ".max.",
                    "selection_threshold": {
                        "upper": 1,
                        "lower": 1
                    }
                }
            ]
        },
        {
            "mode": "J",
            "demand": "mf125",
            "generalized_cost": None,
            "results": {
                "link_volumes": None,
                "turn_volumes": None,
                "od_travel_times": {
                    "shortest_paths": None
                }
            },
            "path_analyses": [
                {
                    "link_component": "@sel",
                    "turn_component": None,
                    "operator": ".max.",
                    "selection_threshold": {
                        "lower": 1,
                        "upper": 1
                    },
                    "path_to_od_composition": {
                        "considered_paths": "SELECTED",
                        "multiply_path_proportions_by": {
                            "analyzed_demand": True,
                            "path_value": False
                        }
                    },
                    "analyzed_demand": None,
                    "results": {
                        "selected_link_volumes": "@volau2_toll_nh",
                        "selected_turn_volumes": None,
                        "od_values": None
                    }
                }
            ]
        },
        {
            "mode": "H",
            "demand": "mf126",
            "generalized_cost": None,
            "results": {
                "link_volumes": None,
                "turn_volumes": None,
                "od_travel_times": {
                    "shortest_paths": None
                }
            },
            "path_analyses": [
                {
                    "link_component": "@sel",
                    "path_to_od_composition": {
                        "considered_paths": "SELECTED",
                        "multiply_path_proportions_by": {
                            "analyzed_demand": True,
                            "path_value": False
                        }
                    },
                    "turn_component": None,
                    "results": {
                        "selected_turn_volumes": None,
                        "selected_link_volumes": "@volau2_toll_hov",
                        "od_values": None
                    },
                    "analyzed_demand": None,
                    "operator": ".max.",
                    "selection_threshold": {
                        "upper": 1,
                        "lower": 1
                    }
                }
            ]
        },
        {
            "mode": "j",
            "demand": "mf127",
            "generalized_cost": None,
            "results": {
                "link_volumes": None,
                "turn_volumes": None,
                "od_travel_times": {
                    "shortest_paths": None
                }
            },
            "path_analyses": [
                {
                    "link_component": "@sel",
                    "turn_component": None,
                    "operator": ".max.",
                    "selection_threshold": {
                        "lower": 1,
                        "upper": 1
                    },
                    "path_to_od_composition": {
                        "considered_paths": "SELECTED",
                        "multiply_path_proportions_by": {
                            "analyzed_demand": True,
                            "path_value": False
                        }
                    },
                    "analyzed_demand": None,
                    "results": {
                        "selected_link_volumes": "@volau3_nt_nh",
                        "selected_turn_volumes": None,
                        "od_values":None
                    }
                }
            ]
        },
        {
            "mode": "i",
            "demand": "mf128",
            "generalized_cost": None,
            "results": {
                "link_volumes": None,
                "turn_volumes": None,
                "od_travel_times": {
                    "shortest_paths": None
                }
            },
            "path_analyses": [
                {
                    "link_component": "@sel",
                    "path_to_od_composition": {
                        "multiply_path_proportions_by": {
                            "path_value": False,
                            "analyzed_demand": True
                        },
                        "considered_paths": "SELECTED"
                    },
                    "turn_component": None,
                    "results": {
                        "selected_turn_volumes": None,
                        "selected_link_volumes": "@volau3_nt_hov",
                        "od_values": None
                    },
                    "analyzed_demand": None,
                    "operator": ".max.",
                    "selection_threshold": {
                        "upper": 1,
                        "lower": 1
                    }
                }
            ]
        },
        {
            "mode": "J",
            "demand": "mf129",
            "generalized_cost": None,
            "results": {
                "link_volumes": None,
                "turn_volumes": None,
                "od_travel_times": {
                    "shortest_paths": None
                }
            },
            "path_analyses": [
                {
                    "link_component": "@sel",
                    "turn_component": None,
                    "operator": ".max.",
                    "selection_threshold": {
                        "lower": 1,
                        "upper": 1
                    },
                    "path_to_od_composition": {
                        "considered_paths": "SELECTED",
                        "multiply_path_proportions_by": {
                            "analyzed_demand": True,
                            "path_value": False
                        }
                    },
                    "analyzed_demand": None,
                    "results": {
                        "selected_link_volumes": "@volau3_toll_nh",
                        "selected_turn_volumes": None,
                        "od_values": None
                    }
                }
            ]
        },
        {
            "mode": "I",
            "demand": "mf130",
            "generalized_cost": None,
            "results": {
                "link_volumes": None,
                "turn_volumes": None,
                "od_travel_times": {
                    "shortest_paths": None
                }
            },
            "path_analyses": [
                {
                    "link_component": "@sel",
                    "path_to_od_composition": {
                        "multiply_path_proportions_by": {
                            "path_value": False,
                            "analyzed_demand": True
                        },
                        "considered_paths": "SELECTED"
                    },
                    "turn_component": None,
                    "results": {
                        "selected_turn_volumes": None,
                        "selected_link_volumes": "@volau3_toll_hov",
                        "od_values": None
                    },
                    "analyzed_demand": None,
                    "operator": ".max.",
                    "selection_threshold": {
                        "upper": 1,
                        "lower": 1
                    }
                }
            ]
        },
        {
            "mode": "d",
            "demand": "mf165",
            "generalized_cost": {
                "link_costs": "@toll_mtruck",
                "perception_factor": 0.015
            },
            "results": {
                "link_volumes": None,
                "turn_volumes": None,
                "od_travel_times": {
                    "shortest_paths": None
                }
            },
            "path_analyses": [
                {
                    "link_component": "@sel",
                    "path_to_od_composition": {
                        "multiply_path_proportions_by": {
                            "path_value": False,
                            "analyzed_demand": True
                        },
                        "considered_paths": "SELECTED"
                    },
                    "turn_component": None,
                    "results": {
                        "selected_turn_volumes": None,
                        "selected_link_volumes": "@volau_ltruck",
                        "od_values": None
                    },
                    "analyzed_demand": None,
                    "operator": ".max.",
                    "selection_threshold": {
                        "upper": 1,
                        "lower": 1
                    }
                }
            ]
        },
        {
            "mode": "e",
            "demand": "mf170",
            "generalized_cost": {
                "link_costs": "@toll_mtruck",
                "perception_factor": 0.003
            },
            "results": {
                "link_volumes": None,
                "turn_volumes": None,
                "od_travel_times": {
                    "shortest_paths": None
                }
            },
            "path_analyses": [
                {
                    "link_component": "@sel",
                    "path_to_od_composition": {
                        "multiply_path_proportions_by": {
                            "path_value": False,
                            "analyzed_demand": True
                        },
                        "considered_paths": "SELECTED"
                    },
                    "turn_component": None,
                    "results": {
                        "selected_turn_volumes": None,
                        "selected_link_volumes": "@volau_mtruck",
                        "od_values": None
                    },
                    "analyzed_demand": None,
                    "operator": ".max.",
                    "selection_threshold": {
                        "upper": 1,
                        "lower": 1
                    }
                }
            ]
        },
        {
            "mode": "f",
            "demand": "mf175",
            "generalized_cost": {
                "link_costs": "@toll_htruck",
                "perception_factor": 0.0024
            },
            "results": {
                "link_volumes": None,
                "turn_volumes": None,
                "od_travel_times": {
                    "shortest_paths": None
                }
            },
            "path_analyses": [
                {
                    "link_component": "@sel",
                    "path_to_od_composition": {
                        "multiply_path_proportions_by": {
                            "path_value": False,
                            "analyzed_demand": True
                        },
                        "considered_paths": "SELECTED"
                    },
                    "turn_component": None,
                    "results": {
                        "selected_turn_volumes": None,
                        "selected_link_volumes": "@volau_htruck",
                        "od_values": None
                    },
                    "analyzed_demand": None,
                    "operator": ".max.",
                    "selection_threshold": {
                        "upper": 1,
                        "lower": 1
                    }
                }
            ]
        }
    ],
    "performance_settings": {
        "number_of_processors": 8
    },
    "background_traffic": None,
    "stopping_criteria": {
        "max_iterations": 15,
        "relative_gap": 0.05,
        "best_relative_gap": 0,
        "normalized_gap": 0
    }
}

# %%
import inro.modeller as m
import os
import glob
import csv
import pandas as pd

mm = m.Modeller()
eb = m.Modeller().emmebank

#tools
import_matrices = mm.tool("tmg.input_output.import_binary_matrix")           
change_matrix = mm.tool("inro.emme.data.matrix.change_matrix_properties")
create_matrix =  mm.tool("inro.emme.data.matrix.create_matrix")
matrix_calculator = mm.tool("inro.emme.matrix_calculation.matrix_calculator")
matrix_transaction = mm.tool('inro.emme.data.matrix.matrix_transaction')
network_calculator = mm.tool("inro.emme.network_calculation.network_calculator")
selectLink = mm.tool("inro.emme.traffic_assignment.sola_traffic_assignment")
create_ea = mm.tool("inro.emme.data.extra_attribute.create_extra_attribute")
init_ea = mm.tool("inro.emme.data.extra_attribute.init_extra_attribute")

#HDR Scripts
common = mm.module('org.emme.common')
#moe = mm.module('org.emme.moe')

matrix_folder = r"\\tore-infs01\PWExternal\451010\281829_GGH\GGHM Runs\2041\MTO_2041_GGH_MTP_328_V105_CS222_20190522"

sc_am = eb.scenario(213)

# %%
networkCalcSpec = {
    "result": None,
    "expression": None,
    "aggregation": None,
    "selections": {
        "link": "all",
    },
    "type": "NETWORK_CALCULATION"
}

# %%
car_list ={
    "trips_am_peak_auto1_nt" :"mf121",
    "trips_am_peak_auto1_toll" :"mf122",
    "trips_am_peak_auto2_nt_hov" :"mf124",
    "trips_am_peak_auto2_nt_nh" :"mf123",
    "trips_am_peak_auto2_toll_hov" :"mf126",
    "trips_am_peak_auto2_toll_nh" :"mf125",
    "trips_am_peak_auto3_nt_hov" :"mf128",
    "trips_am_peak_auto3_nt_nh" :"mf127",
    "trips_am_peak_auto3_toll_hov" :"mf130",
    "trips_am_peak_auto3_toll_nh" :"mf129",}
truck_list ={
    "lt_truck_ampkhr": "mf165",
    "mt_truck_ampkhr": "mf170",
    "ht_truck_ampkhr": "mf175"}

# %%
for matrix_name in matrix_list.keys():
    #matrix_list[matrix_name] = eb.available_matrix_identifier('FULL')
    create_matrix(matrix_id = matrix_list[matrix_name],
                  matrix_name= matrix_name,
                  matrix_description = matrix_name)

# %%
common.import_matrices_from_directory(matrix_folder, car_list, ".mdf",sc_am)

# %%
common.import_matrices_from_directory(matrix_folder, truck_list, ".mdf",eb.scenario(116))

# %%
from copy import deepcopy

# %%
clearNetwork = deepcopy(networkCalcSpec)
clearNetwork["result"] = "@sel"
clearNetwork["expression"] = "0"
network_calculator(clearNetwork)
# Out:
# {'average': 0.0,
#  'expression_type': 'LINK',
#  'maximum': 0.0,
#  'maximum_at': {'i_node': 1001, 'j_node': 10000},
#  'minimum': 0.0,
#  'minimum_at': {'i_node': 1001, 'j_node': 10000},
#  'num_attributes_changed': 0,
#  'num_evaluations': 88664,
#  'num_results_obtained': 88664,
#  'result_type': 'LINK',
#  'sum': 0.0}

# %%
links = pd.read_csv(r"C:\Users\BCRANE\Documents\Long List\HighwaySelectLinkList3.csv")

# %%
links
# Out:
#        Series Express_Collector  ID                      Description     i1  \
# 0  400 Series                No  31  Highway 407 between 400 and 404  32770
# 1  400 Series                No  32          Highway 407 west of 427  41764
# 2  400 Series                No  33             Gardiner east of 427  11111
#
#       j1     i2     j2  i3  j3  i4  j4  Unnamed: 12
# 0  32882  32881  32772   0   0   0   0          NaN
# 1  42853  42852  42304   0   0   0   0          NaN
# 2  11008  12055  16000   0   0   0   0          NaN

# %%
for index, row in links.iterrows():
    print(row.Express_Collector == "Yes")

# %%
vol_eas = ["@volau1_nt","@volau1_toll","@volau2_nt_nh","@volau2_nt_hov","@volau2_toll_nh","@volau2_toll_hov","@volau3_nt_nh",
"@volau3_nt_hov","@volau3_toll_nh","@volau3_toll_hov","@volau_htruck","@volau_mtruck","@volau_ltruck"]

# %%
for index, row in links.iterrows():
    network_calculator(clearNetwork)
    analysisID = row.ID
    tagNetwork = deepcopy(networkCalcSpec)
    tagNetwork["result"] = "@sel"
    tagNetwork["expression"] = "1"
    tagNetwork["selections"]["link"] = "link={},{}".format(row.i1,row.j1)
    network_calculator(tagNetwork)
    tagNetwork["selections"]["link"] = "link={},{}".format(row.i2,row.j2)
    network_calculator(tagNetwork)
    if row.Express_Collector == "Yes":
        tagNetwork["selections"]["link"] = "link={},{}".format(row.i3,row.j3)
        network_calculator(tagNetwork)
        tagNetwork["selections"]["link"] = "link={},{}".format(row.i4,row.j4)
        network_calculator(tagNetwork)

    for ea in vol_eas:
        init_ea(ea,0)
    
    print("starting ta for {}".format(row.Description))
    
    selectLink(solaSpec)
    
    create_ea("LINK","@selvol{}".format(analysisID), "{}".format(row.Description), overwrite = True)
    create_ea("LINK","@selvoltr{}".format(analysisID), "{}".format(row.Description), overwrite = True)

    saveVol = deepcopy(networkCalcSpec)
    saveVol["result"] = "@selvol{}".format(analysisID)
    saveVol["expression"] = "@volau1_nt+@volau1_toll+@volau2_nt_nh+@volau2_nt_hov+@volau2_toll_nh+@volau2_toll_hov+@volau3_nt_nh+\
@volau3_nt_hov+@volau3_toll_nh+@volau3_toll_hov"
    network_calculator(saveVol)
    
    saveTruck =deepcopy(networkCalcSpec)
    saveTruck["result"] = "@selvoltr{}".format(analysisID)
    saveTruck["expression"] = "@volau_htruck+@volau_mtruck+@volau_ltruck"
    network_calculator(saveTruck)

# %%
links = pd.read_csv(r"C:\Users\BCRANE\Documents\Long List\HighwaySelectLinkList3.csv")
for index, row in links.iterrows():
    if row.Express_Collector == "Yes":
        print "ID: {},description: {},  filter: (i =={} && j == {}) \
        || (i == {} && j == {}) || (i == {} && j == {}) || (i == {} && j == {})".format(row.ID,row.Description,row.i1,row.j1,row.i2,row.j2, row.i3,row.j3,row.i4,row.j4) 
    else: 
        print "ID: {},description: {},  filter: (i =={} && j == {}) || (i == {} && j == {})".format(row.ID,row.Description,row.i1,row.j1,row.i2,row.j2)

# %%
create_ea("LINK","@selvoltr{}".format(analysisID), "{}".format(row.Description), overwrite = True)

saveVol = deepcopy(networkCalcSpec)
saveVol["result"] = "@selvol{}".format(analysisID)
saveVol["expression"] = "@volau1_nt+@volau1_toll+@volau2_nt_nh+@volau2_nt_hov+@volau2_toll_nh+@volau2_toll_hov+@volau3_nt_nh+\
@volau3_nt_hov+@volau3_toll_nh+@volau3_toll_hov"
network_calculator(saveVol)

saveTruck =deepcopy(networkCalcSpec)
saveTruck["result"] = "@selvoltr{}".format(analysisID)
saveTruck["expression"] = "@volau_htruck+@volau_mtruck+@volau_ltruck"
network_calculator(saveTruck)
# Out:
# {'average': 0.431964,
#  'expression_type': 'LINK',
#  'maximum': 550.88855,
#  'maximum_at': {'i_node': 31550, 'j_node': 32524},
#  'minimum': 0.0,
#  'minimum_at': {'i_node': 1001, 'j_node': 10000},
#  'num_attributes_changed': 12388,
#  'num_evaluations': 88664,
#  'num_results_obtained': 88664,
#  'result_type': 'LINK',
#  'sum': 38299.679688}
