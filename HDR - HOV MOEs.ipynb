# %%
import inro.modeller as m
import os
import glob
import csv

mm = m.Modeller()
eb = mm.emmebank

#HDR Scripts
common = mm.module('org.emme.common')
moe = mm.module('org.emme.moe')
export_matrices = mm.tool("org.emme.export_binary_matrix")

#tools
create_extra_att = mm.tool("inro.emme.data.extra_attribute.create_extra_attribute")
import_matrices = mm.tool("tmg.input_output.import_binary_matrix")
change_matrix = m.Modeller().tool("inro.emme.data.matrix.change_matrix_properties")
create_matrix =  m.Modeller().tool("inro.emme.data.matrix.create_matrix")
matrix_calculator = m.Modeller().tool("inro.emme.matrix_calculation.matrix_calculator")
assign_traffic = m.Modeller().tool("inro.emme.traffic_assignment.sola_traffic_assignment")

#scenario definitions
scen_base = "2041\\GGHM Base Case\\"
scen_1C_HOV2 = "2041\\Scen1c HOV2plus\\"
scen_1C_HOV3 = "2041\\Scen1c HOV3\\"
scen_4A = "2041\\HOV4A 0-2-2\\"
scen_5A = "2041\\HOV5A 0-2-2\\"
scen_6A = "2041\\HOV6A 0-2-2\\"
scen_1_102 = "2041\\Scen1_Option102\\"


#auto occupancy
sov_oc = 1.2
hov2_oc = 2.2
hov3_oc = 3.3

# %%
#assignment scenario

#scen_name = "2041_base"
#scenario_folder = scen_base
#sc_num_am = 200
#tran_scen = 201

#scen_name = "1A"
#scenario_folder = scen_6A
#sc_num_am = 1
#tran_scen = 109

#scen_name = "1C_HOV2plus"
#scenario_folder = scen_1C_HOV2
#sc_num_am = 2
#tran_scen = 102

#scen_name = "1C_HOV3"
#scenario_folder = scen_1C_HOV3
#sc_num_am = 3
#tran_scen = 103

#scen_name = "2A"
#scenario_folder = scen_6A
#sc_num_am = 4
#tran_scen = 109

#scen_name = "3A"
#scenario_folder = scen_6A
#sc_num_am = 5
#tran_scen = 109

#scen_name = "4A"
#scenario_folder = scen_4A
#sc_num_am = 6
#tran_scen = 106

#scen_name = "5A"
#scenario_folder = scen_5A
#sc_num_am = 7
#tran_scen = 201

#scen_name = "5B"
#scenario_folder = scen_5A
#sc_num_am = 8
#tran_scen = 107

#scen_name = "6A" 
#scenario_folder = scen_6A
#sc_num_am = 9
#tran_scen = 109

#scen_name = "7B"
#scenario_folder = scen_base
#sc_num_am = 10
#tran_scen = 201

#scen_name = "4A_high_tolls"
#scenario_folder = scen_4A
#sc_num_am = 16
#tran_scen = 106

#scen_name = "7C" 
#scenario_folder = scen_base
#sc_num_am = 11
#tran_scen = 201

#scen_name = "Pre-short 3B" 
#scenario_folder = scen_base
#sc_num_am = 12
#tran_scen = 201

#scen_name = "5C" 
#scenario_folder = scen_1_102
#sc_num_am = 13
#tran_scen = 113

scen_name = "6A_no_ramps" 
scenario_folder = scen_6A
sc_num_am = 9
tran_scen = 109

sc_am = eb.scenario(sc_num_am)

matrix_folder = u"P:\\451010\\281829_GGH\\GGHM Runs\\" + scenario_folder

# %%
#clear all full matrices
common.clear_matrices(eb)

#run assignment
moe.prep_SOLA_assignment(matrix_folder,sc_am)
# Out:
# Finished Importing Matrices

# %%
spec = {
    "type": "SOLA_TRAFFIC_ASSIGNMENT",
    "classes": [
        {
            "mode": "j",
            "demand": "mf21",
            "generalized_cost": None,
            "results": {
                "link_volumes": "@volau1_nt",
                "turn_volumes": None,
                "od_travel_times": {
                    "shortest_paths": "mf31"
                }
            },
            "path_analysis": None,
            "cutoff_analysis": None,
            "traversal_analysis": None,
            "analysis": {
                "analyzed_demand": None,
                "results": {
                    "od_values": None,
                    "selected_link_volumes": None,
                    "selected_turn_volumes": None
                }
            }
        },
        {
            "mode": "J",
            "demand": "mf22",
            "generalized_cost": None,
            "results": {
                "link_volumes": "@volau1_toll",
                "turn_volumes": None,
                "od_travel_times": {
                    "shortest_paths": "mf32"
                }
            },
            "path_analysis": None,
            "cutoff_analysis": None,
            "traversal_analysis": None,
            "analysis": {
                "analyzed_demand": None,
                "results": {
                    "od_values": None,
                    "selected_link_volumes": None,
                    "selected_turn_volumes": None
                }
            }
        },
        {
            "mode": "j",
            "demand": "mf23",
            "generalized_cost": None,
            "results": {
                "link_volumes": "@volau2_nt_nh",
                "turn_volumes": None,
                "od_travel_times": {
                    "shortest_paths": "mf33"
                }
            },
            "path_analysis": None,
            "cutoff_analysis": None,
            "traversal_analysis": None,
            "analysis": {
                "analyzed_demand": None,
                "results": {
                    "od_values": None,
                    "selected_link_volumes": None,
                    "selected_turn_volumes": None
                }
            }
        },
        {
            "mode": "h",
            "demand": "mf24",
            "generalized_cost": None,
            "results": {
                "link_volumes": "@volau2_nt_hov",
                "turn_volumes": None,
                "od_travel_times": {
                    "shortest_paths": "mf34"
                }
            },
            "path_analysis": None,
            "cutoff_analysis": None,
            "traversal_analysis": None,
            "analysis": {
                "analyzed_demand": None,
                "results": {
                    "od_values": None,
                    "selected_link_volumes": None,
                    "selected_turn_volumes": None
                }
            }
        },
        {
            "mode": "J",
            "demand": "mf25",
            "generalized_cost": None,
            "results": {
                "link_volumes": "@volau2_toll_nh",
                "turn_volumes": None,
                "od_travel_times": {
                    "shortest_paths": "mf35"
                }
            },
            "path_analysis": None,
            "cutoff_analysis": None,
            "traversal_analysis": None,
            "analysis": {
                "analyzed_demand": None,
                "results": {
                    "od_values": None,
                    "selected_link_volumes": None,
                    "selected_turn_volumes": None
                }
            }
        },
        {
            "mode": "H",
            "demand": "mf26",
            "generalized_cost": None,
            "results": {
                "link_volumes": "@volau2_toll_hov",
                "turn_volumes": None,
                "od_travel_times": {
                    "shortest_paths": "mf36"
                }
            },
            "path_analysis": None,
            "cutoff_analysis": None,
            "traversal_analysis": None,
            "analysis": {
                "analyzed_demand": None,
                "results": {
                    "od_values": None,
                    "selected_link_volumes": None,
                    "selected_turn_volumes": None
                }
            }
        },
        {
            "mode": "j",
            "demand": "mf27",
            "generalized_cost": None,
            "results": {
                "link_volumes": "@volau3_nt_nh",
                "turn_volumes":None,
                "od_travel_times": {
                    "shortest_paths": "mf37"
                }
            },
            "path_analysis": None,
            "cutoff_analysis": None,
            "traversal_analysis":None,
            "analysis": {
                "analyzed_demand": None,
                "results": {
                    "od_values": None,
                    "selected_link_volumes": None,
                    "selected_turn_volumes": None
                }
            }
        },
        {
            "mode": "i",
            "demand": "mf28",
            "generalized_cost": None,
            "results": {
                "link_volumes": "@volau3_nt_hov",
                "turn_volumes": None,
                "od_travel_times": {
                    "shortest_paths": "mf38"
                }
            },
            "path_analysis": None,
            "cutoff_analysis": None,
            "traversal_analysis": None,
            "analysis": {
                "analyzed_demand": None,
                "results": {
                    "od_values": None,
                    "selected_link_volumes": None,
                    "selected_turn_volumes": None
                }
            }
        },
        {
            "mode": "J",
            "demand": "mf29",
            "generalized_cost": None,
            "results": {
                "link_volumes": "@volau3_toll_nh",
                "turn_volumes": None,
                "od_travel_times": {
                    "shortest_paths": "mf39"
                }
            },
            "path_analysis": None,
            "cutoff_analysis": None,
            "traversal_analysis": None,
            "analysis": {
                "analyzed_demand": None,
                "results": {
                    "od_values": None,
                    "selected_link_volumes": None,
                    "selected_turn_volumes": None
                }
            }
        },
        {
            "mode": "I",
            "demand": "mf30",
            "generalized_cost": None,
            "results": {
                "link_volumes": "@volau3_toll_hov",
                "turn_volumes": None,
                "od_travel_times": {
                    "shortest_paths": "mf40"
                }
            },
            "path_analysis": None,
            "cutoff_analysis": None,
            "traversal_analysis": None,
            "analysis": {
                "analyzed_demand": None,
                "results": {
                    "od_values": None,
                    "selected_link_volumes": None,
                    "selected_turn_volumes": None
                }
            }
        },
        {
            "mode": "d",
            "demand": "mf65",
            "generalized_cost": {
                "link_costs": "@toll_mtruck",
                "perception_factor": 0.015
            },
            "results": {
                "link_volumes": "@volau_ltruck",
                "turn_volumes": None,
                "od_travel_times": {
                    "shortest_paths": "mf66"
                }
            },
            "path_analysis": None,
            "cutoff_analysis": None,
            "traversal_analysis": None,
            "analysis": {
                "analyzed_demand": None,
                "results": {
                    "od_values": None,
                    "selected_link_volumes": None,
                    "selected_turn_volumes": None
                }
            }
        },
        {
            "mode": "e",
            "demand": "mf70",
            "generalized_cost": {
                "link_costs": "@toll_mtruck",
                "perception_factor": 0.003
            },
            "results": {
                "link_volumes": "@volau_mtruck",
                "turn_volumes": None,
                "od_travel_times": {
                    "shortest_paths": "mf71"
                }
            },
            "path_analysis": None,
            "cutoff_analysis": None,
            "traversal_analysis": None,
            "analysis": {
                "analyzed_demand": None,
                "results": {
                    "od_values": None,
                    "selected_link_volumes": None,
                    "selected_turn_volumes": None
                }
            }
        },
        {
            "mode": "f",
            "demand": "mf75",
            "generalized_cost": {
                "link_costs": "@toll_htruck",
                "perception_factor": 0.0024
            },
            "results": {
                "link_volumes": "@volau_htruck",
                "turn_volumes": None,
                "od_travel_times": {
                    "shortest_paths": "mf76"
                }
            },
            "path_analysis": None,
            "cutoff_analysis": None,
            "traversal_analysis": None,
            "analysis": {
                "analyzed_demand": None,
                "results": {
                    "od_values": None,
                    "selected_link_volumes": None,
                    "selected_turn_volumes": None
                }
            }
        }
    ],
    "path_analysis": None,
    "cutoff_analysis": None,
    "traversal_analysis": None,
    "performance_settings": {
        "number_of_processors": 8
    },
    
    "background_traffic": None,
    "stopping_criteria": {
        "max_iterations": 30,
        "relative_gap": 0.05,
        "best_relative_gap": 0,
        "normalized_gap": 0
    }
}
#assign_traffic(specification = spec, scenario = sc_am)
# Out:
# {'initialization': {'all_classes': {'demand': {'not_assigned': 102013.23,
#     'total': 2295549.78}},
#   'classes': [{'demand': {'total': 1363853.0}},
#    {'demand': {'total': 71155.28}},
#    {'demand': {'total': 486447.75}},
#    {'demand': {'total': 42268.5}},
#    {'demand': {'total': 5106.14}},
#    {'demand': {'total': 40124.93}},
#    {'demand': {'total': 53753.99}},
#    {'demand': {'total': 5702.85}},
#    {'demand': {'total': 746.88}},
#    {'demand': {'total': 6087.66}},
#    {'demand': {'total': 116846.25}},
#    {'demand': {'total': 55102.38}},
#    {'demand': {'total': 48354.15}}],
#   'cpu_time': {'shortest_paths': (61.8, 61.8),
#    'step_length': (0.0, 0.0),
#    'total': (61.9, 61.9),
#    'update': (0.1, 0.1)},
#   'objective_func': {'current_value': 379626000.0}},
#  'iterations': [{'avg_trip_costs': {'network': 1061.16,
#     'shortest_paths': 20.55},
#    'cpu_time': {'shortest_paths': (65.9, 127.8),
#     'step_length': (0.1, 0.1),
# ...

# %%
#export travel time matrices
out_dir = u"P:\\451010\\281829_GGH\\HDR_assignment_outputs\\2041\\" + scen_name + "\\"
if not os.path.exists(out_dir):
    os.makedirs(out_dir)
moe.export_auto_los(out_dir,sc_am)

# %%
#import HDR assigned skims
assigned_folder = u"P:\\451010\\281829_GGH\\HDR_assignment_outputs\\2041\\" + scen_name + "\\"

assigned_list = {"time_auto1_nt": "mf31",
               "time_auto1_toll": "mf32",
               "time_auto2_nt_nh": "mf33",
               "time_auto2_nt_hov": "mf34",
               "time_auto2_toll_nh": "mf35",
               "time_auto2_toll_hov": "mf36",
               "time_auto3_nt_nh": "mf37",
               "time_auto3_nt_hov": "mf38",
               "time_auto3_toll_nh": "mf39",
               "time_auto3_toll_hov": "mf40",
               "truck.time.heavy": "mf76",
               "truck.time.medium": "mf71",
               "truck.time.light": "mf66"
               }
               
common.import_matrices_from_directory(assigned_folder, assigned_list, ".mdf",sc_num_am)
# Out:
# Finished Importing Matrices

# %%
#transit time - peak

min_transit_time_peak = eb.available_matrix_identifier('FULL')
create_matrix(matrix_id = min_transit_time_peak,
    matrix_name= "peak.min.transit.time",
    matrix_description = "peak.minimum.transit.time")
# Out:
# FullMatrix(mf1)

# %%
#min_transit_time_peak ="mf1"
time_period = "peak"
common.minimum_transit_time(time_period, min_transit_time_peak, matrix_folder, sc_am)
# Out:
# Finished Importing Matrices
# Finished Calculating Transit Travel Times

# %%
min_transit_time_peak = "mf1"
MOEs = {}
MOEs = moe.MOE_HOV(MOEs, matrix_folder, min_transit_time_peak, sc_am,sov_oc, hov2_oc, hov3_oc ,eb.scenario(tran_scen))
# Out:
# Finished Importing Matrices
# 155702.3
# 4395065.0
# 60085.79
# 2067557.0
# Finished Calculating MOEs

# %%
ntwk_am = sc_am.get_network()
total_hov_lane_km = 0.0
for link in ntwk_am.links():
    if link.length > 0 and ntwk_am.mode('c') in link.modes and\
        (ntwk_am.mode('i') in link.modes or ntwk_am.mode('h') in link.modes\
        or ntwk_am.mode('J') in link.modes or ntwk_am.mode('I') in link.modes or ntwk_am.mode('H') in link.modes
        or ntwk_am.mode('f') in link.modes or ntwk_am.mode('e') in link.modes or ntwk_am.mode('d') in link.modes):
            if ntwk_am.mode('j') not in link.modes and ntwk_am.mode('f') in link.modes and ntwk_am.mode('J') not in link.modes:
                    total_hov_lane_km += link.num_lanes*link.length
print total_hov_lane_km
# Out:
# 0.0

# %%
save_path = "C:\\Users\\mnasterska\\Documents\\Projects\\GGH\\MOE"
with open (os.path.join(save_path, "HOV_" + scen_name +".csv"),"wb") as csvfile:
    csvwriter = csv.writer(csvfile, delimiter = ",", quoting = csv.QUOTE_MINIMAL)
    csvwriter.writerow(["MOE Number", "Value"])
    for line in MOEs:
        csvwriter.writerow([line, MOEs[line]])

# %%
#matrices
matrix_list = {
    sov_demand_pk : "",
    hov2_demand_pk : "",
    hov3_demand_pk : "",
    bike_demand_pk : "",
    walk_demand_pk : "",
    transit_demand_pk : "",
    hbw_demand_pk : "",
    sov_demand_am : "",
    hov2_demand_am : "",
    hov3_demand_am : "",
    transit_2hr_demand_am : "",
    truck_l_demand_am : "",
    truck_m_demand_am : "",
    truck_h_demand_am : "",
    active_time : "",
    sov_dist_am : "",
    sov_time_am: "",
    hov2_time_am: "",
    hov3_time_am : "",
    sov_time_md : "",
    hov2_time_md: "",
    hov3_time_md : "",
    sov_demand_pk : ""
              }

# %%
#define matrix inputs

# demand
# peak period - 7 hrs
sov_demand_pk = "auto_sov_PkPd"
hov2_demand_pk = "auto_hov2_PkPd"
hov3_demand_pk = "auto_hov3_PkPd"
bike_demand_pk = "Bike_PkPd"
walk_demand_pk = "Walk_PkPd"
transit_demand_pk = "PnA_Transit_PkPd"
hbw_demand_pk = "trips_peak_all_modes_hbw_all_segments"

#am peak hour
sov_demand_am = "auto_sov_AMPk"
hov2_demand_am = "auto_hov2_AMPk"
hov3_demand_am = "auto_hov3_AMPk"
transit_2hr_demand_am = "total_transit_AMPk"
truck_l_demand_am = "lt_truck_ampkhr"
truck_m_demand_am = "mt_truck_ampkhr"
truck_h_demand_am = "ht_truck_ampkhr"

# distance
sov_dist_am = "skim.am_peak.auto.sov.dist"

# travel time
active_time = "skim.static.bike.time"
sov_time_am = "skim.am_peak.auto.sov.time"
hov2_time_am = "skim.am_peak.auto.hov2.time"
hov3_time_am = "skim.am_peak.auto.hov3.time"

min_transit_time_peak = eb.available_matrix_identifier('FULL')
create_matrix(matrix_id = min_transit_time_peak,
    matrix_name= "peak.min.transit.time",
    matrix_description = "peak.minimum.transit.time")
# Out:
# FullMatrix(mf1)

# %%
### IMPORT ALL MATRICES IN SUBFOLDERS ###
for matrix_name in matrix_list.keys():
    matrix_list[matrix_name] = eb.available_matrix_identifier('FULL')
    create_matrix(matrix_id = matrix_list[matrix_name],
                  matrix_name= matrix_name,
                  matrix_description = matrix_name)

common.import_matrices_from_directory(matrix_folder, matrix_list, ".mdf")
# Out:
# Imported matrix: auto_hov2_AMPk.mdf to: mf21
# Imported matrix: auto_hov2_PkPd.mdf to: mf12
# Imported matrix: auto_hov3_AMPk.mdf to: mf8
# Imported matrix: auto_hov3_PkPd.mdf to: mf16
# Imported matrix: auto_sov_AMPk.mdf to: mf22
# Imported matrix: auto_sov_PkPd.mdf to: mf9
# Imported matrix: Bike_PkPd.mdf to: mf20
# Imported matrix: PnA_Transit_PkPd.mdf to: mf3
# Imported matrix: total_transit_AMPk.mdf to: mf23
# Imported matrix: trips_peak_all_modes_hbw_all_segments.mdf to: mf10
# Imported matrix: Walk_PkPd.mdf to: mf2
# Imported matrix: skim.am_peak.auto.hov2.time.mdf to: mf7
# Imported matrix: skim.am_peak.auto.hov3.time.mdf to: mf13
# Imported matrix: skim.am_peak.auto.sov.dist.mdf to: mf18
# Imported matrix: skim.am_peak.auto.sov.time.mdf to: mf11
# Imported matrix: skim.midday.auto.hov2.time.mdf to: mf14
# Imported matrix: skim.midday.auto.hov3.time.mdf to: mf15
# Imported matrix: skim.midday.auto.sov.time.mdf to: mf4
# Imported matrix: skim.static.bike.time.mdf to: mf6
# ...

# %%
#delete all matrices
common.clear_matrices(eb,["mf31","mf38","mf33", min_transit_time_peak])

# %%
sc_source = eb.scenario(29)

ntwk = sc_source.get_network()

total_vkt = 0.0

for link in ntwk.links():
    total_vkt += (link['@volau2_nt_hov']+link['@volau2_toll_hov']+link['@volau3_nt_hov']+link['@volau3_toll_hov'])*link.length
        
print total_vkt
# Out:
# 368712.80618
