# %%
solaSpec = {
    "type": "SOLA_TRAFFIC_ASSIGNMENT",
    "classes": [
        {
            "mode": "j",
            "demand": "mf121",
            "generalized_cost": None,
            "results": {
                "link_volumes": None,
                "turn_volumes": None,
                "od_travel_times": {
                    "shortest_paths": None
                }
            },
            "path_analyses": None
        },
        {
            "mode": "J",
            "demand": "mf122",
            "generalized_cost": None,
            "results": {
                "link_volumes": None,
                "turn_volumes": None,
                "od_travel_times": {
                    "shortest_paths": None
                }
            },
            "path_analyses": None
        },
        {
            "mode": "j",
            "demand": "mf123",
            "generalized_cost": None,
            "results": {
                "link_volumes": None,
                "turn_volumes": None,
                "od_travel_times": {
                    "shortest_paths": None
                }
            },
            "path_analyses": None
        },
        {
            "mode": "h",
            "demand": "mf124",
            "generalized_cost": None,
            "results": {
                "link_volumes": None,
                "turn_volumes": None,
                "od_travel_times": {
                    "shortest_paths": None
                }
            },
            "path_analyses": None
        },
        {
            "mode": "J",
            "demand": "mf125",
            "generalized_cost": None,
            "results": {
                "link_volumes": None,
                "turn_volumes": None,
                "od_travel_times": {
                    "shortest_paths": None
                }
            },
            "path_analyses":None
        },
        {
            "mode": "H",
            "demand": "mf126",
            "generalized_cost": None,
            "results": {
                "link_volumes": None,
                "turn_volumes": None,
                "od_travel_times": {
                    "shortest_paths": None
                }
            },
            "path_analyses": None
        },
        {
            "mode": "j",
            "demand": "mf127",
            "generalized_cost": None,
            "results": {
                "link_volumes": None,
                "turn_volumes": None,
                "od_travel_times": {
                    "shortest_paths": None
                }
            },
            "path_analyses":None
        },
        {
            "mode": "i",
            "demand": "mf128",
            "generalized_cost": None,
            "results": {
                "link_volumes": None,
                "turn_volumes": None,
                "od_travel_times": {
                    "shortest_paths": None
                }
            },
            "path_analyses": None
        },
        {
            "mode": "J",
            "demand": "mf129",
            "generalized_cost": None,
            "results": {
                "link_volumes": None,
                "turn_volumes": None,
                "od_travel_times": {
                    "shortest_paths": None
                }
            },
            "path_analyses": None
        },
        {
            "mode": "I",
            "demand": "mf130",
            "generalized_cost": None,
            "results": {
                "link_volumes": None,
                "turn_volumes": None,
                "od_travel_times": {
                    "shortest_paths": None
                }
            },
            "path_analyses": None
        },
        {
            "mode": "d",
            "demand": "mf165",
            "generalized_cost": {
                "link_costs": "@toll_mtruck",
                "perception_factor": 0.015
            },
            "results": {
                "link_volumes": None,
                "turn_volumes": None,
                "od_travel_times": {
                    "shortest_paths": None
                }
            },
            "path_analyses": [
                {
                    "link_component": "@sel",
                    "path_to_od_composition": {
                        "multiply_path_proportions_by": {
                            "path_value": False,
                            "analyzed_demand": True
                        },
                        "considered_paths": "SELECTED"
                    },
                    "turn_component": None,
                    "results": {
                        "selected_turn_volumes": None,
                        "selected_link_volumes": "@volau_ltruck",
                        "od_values": None
                    },
                    "analyzed_demand": None,
                    "operator": ".max.",
                    "selection_threshold": {
                        "upper": 1,
                        "lower": 1
                    }
                }
            ]
        },
        {
            "mode": "e",
            "demand": "mf170",
            "generalized_cost": {
                "link_costs": "@toll_mtruck",
                "perception_factor": 0.003
            },
            "results": {
                "link_volumes": None,
                "turn_volumes": None,
                "od_travel_times": {
                    "shortest_paths": None
                }
            },
            "path_analyses": [
                {
                    "link_component": "@sel",
                    "path_to_od_composition": {
                        "multiply_path_proportions_by": {
                            "path_value": False,
                            "analyzed_demand": True
                        },
                        "considered_paths": "SELECTED"
                    },
                    "turn_component": None,
                    "results": {
                        "selected_turn_volumes": None,
                        "selected_link_volumes": "@volau_mtruck",
                        "od_values": None
                    },
                    "analyzed_demand": None,
                    "operator": ".max.",
                    "selection_threshold": {
                        "upper": 1,
                        "lower": 1
                    }
                }
            ]
        },
        {
            "mode": "f",
            "demand": "mf175",
            "generalized_cost": {
                "link_costs": "@toll_htruck",
                "perception_factor": 0.0024
            },
            "results": {
                "link_volumes": None,
                "turn_volumes": None,
                "od_travel_times": {
                    "shortest_paths": None
                }
            },
            "path_analyses": [
                {
                    "link_component": "@sel",
                    "path_to_od_composition": {
                        "multiply_path_proportions_by": {
                            "path_value": False,
                            "analyzed_demand": True
                        },
                        "considered_paths": "SELECTED"
                    },
                    "turn_component": None,
                    "results": {
                        "selected_turn_volumes": None,
                        "selected_link_volumes": "@volau_htruck",
                        "od_values": None
                    },
                    "analyzed_demand": None,
                    "operator": ".max.",
                    "selection_threshold": {
                        "upper": 1,
                        "lower": 1
                    }
                }
            ]
        }
    ],
    "performance_settings": {
        "number_of_processors": 8
    },
    "background_traffic": None,
    "stopping_criteria": {
        "max_iterations": 30,
        "relative_gap": 0.05,
        "best_relative_gap": 0,
        "normalized_gap": 0
    }
}

# %%
import inro.modeller as m
import os
import glob
import csv
import pandas as pd

mm = m.Modeller()
eb = m.Modeller().emmebank

#tools
import_matrices = mm.tool("tmg.input_output.import_binary_matrix")           
change_matrix = mm.tool("inro.emme.data.matrix.change_matrix_properties")
create_matrix =  mm.tool("inro.emme.data.matrix.create_matrix")
matrix_calculator = mm.tool("inro.emme.matrix_calculation.matrix_calculator")
matrix_transaction = mm.tool('inro.emme.data.matrix.matrix_transaction')
network_calculator = mm.tool("inro.emme.network_calculation.network_calculator")
selectLink = mm.tool("inro.emme.traffic_assignment.sola_traffic_assignment")
create_ea = mm.tool("inro.emme.data.extra_attribute.create_extra_attribute")
init_ea = mm.tool("inro.emme.data.extra_attribute.init_extra_attribute")

#HDR Scripts
common = mm.module('org.emme.common')
#moe = mm.module('org.emme.moe')

matrix_folder = r"\\tore-infs01\PWExternal\451010\281829_GGH\GGHM Runs\2041\MTO_2041_GGH_MTP_328_V105_CS222_20190522"

sc_am = eb.scenario(210)

# %%
networkCalcSpec = {
    "result": None,
    "expression": None,
    "aggregation": None,
    "selections": {
        "link": "all",
    },
    "type": "NETWORK_CALCULATION"
}

# %%
car_list ={
    "trips_am_peak_auto1_nt" :"mf121",
    "trips_am_peak_auto1_toll" :"mf122",
    "trips_am_peak_auto2_nt_hov" :"mf124",
    "trips_am_peak_auto2_nt_nh" :"mf123",
    "trips_am_peak_auto2_toll_hov" :"mf126",
    "trips_am_peak_auto2_toll_nh" :"mf125",
    "trips_am_peak_auto3_nt_hov" :"mf128",
    "trips_am_peak_auto3_nt_nh" :"mf127",
    "trips_am_peak_auto3_toll_hov" :"mf130",
    "trips_am_peak_auto3_toll_nh" :"mf129",}
truck_list ={
    "lt_truck_ampkhr": "mf165",
    "mt_truck_ampkhr": "mf170",
    "ht_truck_ampkhr": "mf175"}

# %%
for matrix_name in matrix_list.keys():
    #matrix_list[matrix_name] = eb.available_matrix_identifier('FULL')
    create_matrix(matrix_id = matrix_list[matrix_name],
                  matrix_name= matrix_name,
                  matrix_description = matrix_name)

# %%
common.import_matrices_from_directory(matrix_folder, car_list, ".mdf",sc_am)

# %%
common.import_matrices_from_directory(matrix_folder, truck_list, ".mdf",eb.scenario(116))

# %%
from copy import deepcopy

# %%
clearNetwork = deepcopy(networkCalcSpec)
clearNetwork["result"] = "@sel"
clearNetwork["expression"] = "0"
network_calculator(clearNetwork)
# Out:
# {'average': 0.0,
#  'expression_type': 'LINK',
#  'maximum': 0.0,
#  'maximum_at': {'i_node': 1001, 'j_node': 10000},
#  'minimum': 0.0,
#  'minimum_at': {'i_node': 1001, 'j_node': 10000},
#  'num_attributes_changed': 2,
#  'num_evaluations': 88664,
#  'num_results_obtained': 88664,
#  'result_type': 'LINK',
#  'sum': 0.0}

# %%
links = pd.read_csv(r"C:\Users\BCRANE\Documents\Gap Analysis\SelectLinks.csv")

# %%
links
# Out:
#     ID                       Description     i1     j1     i2     j2
# 0   21          401 west of Homer Watson  82964  82965  82966  82967
# 1   22  401 between Kitchener and Guelph  85420  85421  85399  85175
# 2   23                401 east of Guelph  85517  85406  85254  85518
# 3   24                Hwy 8 north of 401  83415  83361  83370  83416
# 4   25      Hwy 7 betwn Kitch and Guelph  85500  85501  85502  85499
# 5   26        Hwy 7 btwn Strat and Kitch  82156  82157  82158  82159
# 6   27             Hwy 85 north of Hwy 8  82871  82865  82867  82868
# 7   28                Hwy 6 north of 401  85426  85427  85168  85416
# 8   29                Hwy 6 south of 401  85176  85172  85172  85176
# 9   30         Hwy 24 south of Cambridge  83460  83459  83459  83460
# 10  31          Hwy 8 south of Cambridge  83916  83598  83598  83916

# %%
vol_eas = ["@volau1_nt","@volau1_toll","@volau2_nt_nh","@volau2_nt_hov","@volau2_toll_nh","@volau2_toll_hov","@volau3_nt_nh",
"@volau3_nt_hov","@volau3_toll_nh","@volau3_toll_hov","@volau_htruck","@volau_mtruck","@volau_ltruck"]

# %%
for index, row in links.iterrows():
#for index, row in lastLinks.iterrows():
#for index, row in camLink.iterrows():
    network_calculator(clearNetwork)
    analysisID = row.ID
    tagNetwork = deepcopy(networkCalcSpec)
    tagNetwork["result"] = "@sel"
    tagNetwork["expression"] = "1"
    tagNetwork["selections"]["link"] = "link={},{}".format(row.i1,row.j1)
    network_calculator(tagNetwork)
    tagNetwork["selections"]["link"] = "link={},{}".format(row.i2,row.j2)
    
    network_calculator(tagNetwork)
    
    for ea in vol_eas:
        init_ea(ea,0)
    
    print("starting ta for {}".format(row.Description))
    
    selectLink(solaSpec)
    
    create_ea("LINK","@selvol{}".format(analysisID), "Vol {}".format(row.Description), overwrite = True)
    
    saveVol = deepcopy(networkCalcSpec)
    saveVol["result"] = "@selvol{}".format(analysisID)
    saveVol["expression"] = "@volau_htruck+@volau_mtruck+@volau_ltruck"
    network_calculator(saveVol)

# %%
create_ea("LINK","@selvol6", "Vol Hwy 7 btwn Stratford and Kitchener", overwrite = True)

saveVol = deepcopy(networkCalcSpec)
saveVol["result"] = "@selvol6"
saveVol["expression"] = "@volau1_nt+@volau1_toll+@volau2_nt_nh+@volau2_nt_hov+@volau2_toll_nh+@volau2_toll_hov+@volau3_nt_nh+\
@volau3_nt_hov+@volau3_toll_nh+@volau3_toll_hov+@volau_htruck+@volau_mtruck+@volau_ltruck"
network_calculator(saveVol)
# Out:
# {'average': 6.60603,
#  'expression_type': 'LINK',
#  'maximum': 2370.875488,
#  'maximum_at': {'i_node': 82158, 'j_node': 82159},
#  'minimum': 0.0,
#  'minimum_at': {'i_node': 1003, 'j_node': 12699},
#  'num_attributes_changed': 72802,
#  'num_evaluations': 88664,
#  'num_results_obtained': 88664,
#  'result_type': 'LINK',
#  'sum': 585717.0}

# %%
addAtribute = "@volau_htruck+@volau_mtruck+@volau_ltruck"

# %%
addAtribute
# Out:
# '@volau1_nt+@volau1_toll+@volau2_nt_nh+@volau2_nt_hov+@volau2_toll_nh+@volau2_toll_hov+@volau3_nt_nh+@volau3_nt_hov+@volau3_toll_nh+@volau3_toll_hov+@volau_htruck+@volau_mtruck+@volau_ltruck'
