# %% [markdown]
# #GGHM v4 - Develop O-D Transit Trip Matrices (AM Peak) - For HDR Script
#
# This script imports transit trip matrices from the Bulter for to assist with the HDR custom assignment / skim script

# %%
import inro.modeller as m
mm = m.Modeller()
gghm_api = mm.module('gghm.internal.api_interface')

butler = gghm_api.get_matrix_butler("MX-RTP-171127-Sched3V7-41-DoMinv2-0330N")
eb = mm.emmebank

# %% [markdown]
# ###Load Matrices

# %%
#matrix = butler.load_matrix('')

#load peak total person matrices by market segments, for total person trips calc

butler.load_matrix('trips.hbw.peak.train.s2s', target_mfid="mf140", scenario_id="101")
butler.load_matrix('trips.hbw.peak.subway.s2s', target_mfid="mf141", scenario_id="101")
butler.load_matrix('trips.hbw.peak.train.access.transit', target_mfid="mf142", scenario_id="101")
butler.load_matrix('trips.hbw.peak.train.egress.transit', target_mfid="mf143", scenario_id="101")
butler.load_matrix('trips.hbw.peak.subway.access.transit', target_mfid="mf144", scenario_id="101")
butler.load_matrix('trips.hbw.peak.subway.egress.transit', target_mfid="mf145", scenario_id="101")
butler.load_matrix('trips.hbw.peak.express_bus', target_mfid="mf146", scenario_id="101")
butler.load_matrix('trips.hbw.peak.drive_to_and_from', target_mfid="mf147", scenario_id="101")
butler.load_matrix('trips.hbw.peak.train.transfer.s2s', target_mfid="mf148", scenario_id="101")
butler.load_matrix('trips.hbw.peak.train.transfer.ztsa', target_mfid="mf149", scenario_id="101")
butler.load_matrix('trips.hbw.peak.train.access.walk', target_mfid="mf150", scenario_id="101")
butler.load_matrix('trips.hbw.peak.train.egress.walk', target_mfid="mf151", scenario_id="101")
butler.load_matrix('trips.hbw.peak.subway.access.walk', target_mfid="mf152", scenario_id="101")
butler.load_matrix('trips.hbw.peak.subway.egress.walk', target_mfid="mf153", scenario_id="101")
butler.load_matrix('trips.hbw.peak.express_bus.walk', target_mfid="mf154", scenario_id="101")
butler.load_matrix('trips.hbw.peak.express_bus.drive', target_mfid="mf155", scenario_id="101")
butler.load_matrix('trips.hbw.peak.local_bus.walk', target_mfid="mf156", scenario_id="101")
butler.load_matrix('trips.hbw.peak.local_bus.drive', target_mfid="mf157", scenario_id="101")
butler.load_matrix('trips.hbw.peak.rapid_bus.walk', target_mfid="mf158", scenario_id="101")
butler.load_matrix('trips.hbw.peak.rapid_bus.drive', target_mfid="mf159", scenario_id="101")
butler.load_matrix('trips.hbu.peak.train.s2s', target_mfid="mf160", scenario_id="101")
butler.load_matrix('trips.hbu.peak.subway.s2s', target_mfid="mf161", scenario_id="101")
butler.load_matrix('trips.hbu.peak.train.access.transit', target_mfid="mf162", scenario_id="101")
butler.load_matrix('trips.hbu.peak.train.egress.transit', target_mfid="mf163", scenario_id="101")
butler.load_matrix('trips.hbu.peak.subway.access.transit', target_mfid="mf164", scenario_id="101")
butler.load_matrix('trips.hbu.peak.subway.egress.transit', target_mfid="mf165", scenario_id="101")
butler.load_matrix('trips.hbu.peak.express_bus', target_mfid="mf166", scenario_id="101")
butler.load_matrix('trips.hbu.peak.drive_to_and_from', target_mfid="mf167", scenario_id="101")
butler.load_matrix('trips.hbu.peak.train.transfer.s2s', target_mfid="mf168", scenario_id="101")
butler.load_matrix('trips.hbu.peak.train.transfer.ztsa', target_mfid="mf169", scenario_id="101")
butler.load_matrix('trips.hbu.peak.train.access.walk', target_mfid="mf170", scenario_id="101")
butler.load_matrix('trips.hbu.peak.train.egress.walk', target_mfid="mf171", scenario_id="101")
butler.load_matrix('trips.hbu.peak.subway.access.walk', target_mfid="mf172", scenario_id="101")
butler.load_matrix('trips.hbu.peak.subway.egress.walk', target_mfid="mf173", scenario_id="101")
butler.load_matrix('trips.hbu.peak.express_bus.walk', target_mfid="mf174", scenario_id="101")
butler.load_matrix('trips.hbu.peak.express_bus.drive', target_mfid="mf175", scenario_id="101")
butler.load_matrix('trips.hbu.peak.local_bus.walk', target_mfid="mf176", scenario_id="101")
butler.load_matrix('trips.hbu.peak.local_bus.drive', target_mfid="mf177", scenario_id="101")
butler.load_matrix('trips.hbu.peak.rapid_bus.walk', target_mfid="mf178", scenario_id="101")
butler.load_matrix('trips.hbu.peak.rapid_bus.drive', target_mfid="mf179", scenario_id="101")
butler.load_matrix('trips.hbo.peak.train.s2s', target_mfid="mf180", scenario_id="101")
butler.load_matrix('trips.hbo.peak.subway.s2s', target_mfid="mf181", scenario_id="101")
butler.load_matrix('trips.hbo.peak.train.access.transit', target_mfid="mf182", scenario_id="101")
butler.load_matrix('trips.hbo.peak.train.egress.transit', target_mfid="mf183", scenario_id="101")
butler.load_matrix('trips.hbo.peak.subway.access.transit', target_mfid="mf184", scenario_id="101")
butler.load_matrix('trips.hbo.peak.subway.egress.transit', target_mfid="mf185", scenario_id="101")
butler.load_matrix('trips.hbo.peak.express_bus', target_mfid="mf186", scenario_id="101")
butler.load_matrix('trips.hbo.peak.drive_to_and_from', target_mfid="mf187", scenario_id="101")
butler.load_matrix('trips.hbo.peak.train.transfer.s2s', target_mfid="mf188", scenario_id="101")
butler.load_matrix('trips.hbo.peak.train.transfer.ztsa', target_mfid="mf189", scenario_id="101")
butler.load_matrix('trips.hbo.peak.train.access.walk', target_mfid="mf190", scenario_id="101")
butler.load_matrix('trips.hbo.peak.train.egress.walk', target_mfid="mf191", scenario_id="101")
butler.load_matrix('trips.hbo.peak.subway.access.walk', target_mfid="mf192", scenario_id="101")
butler.load_matrix('trips.hbo.peak.subway.egress.walk', target_mfid="mf193", scenario_id="101")
butler.load_matrix('trips.hbo.peak.express_bus.walk', target_mfid="mf194", scenario_id="101")
butler.load_matrix('trips.hbo.peak.express_bus.drive', target_mfid="mf195", scenario_id="101")
butler.load_matrix('trips.hbo.peak.local_bus.walk', target_mfid="mf196", scenario_id="101")
butler.load_matrix('trips.hbo.peak.local_bus.drive', target_mfid="mf197", scenario_id="101")
butler.load_matrix('trips.hbo.peak.rapid_bus.walk', target_mfid="mf198", scenario_id="101")
butler.load_matrix('trips.hbo.peak.rapid_bus.drive', target_mfid="mf199", scenario_id="101")
butler.load_matrix('trips.hbm.peak.train.s2s', target_mfid="mf200", scenario_id="101")
butler.load_matrix('trips.hbm.peak.subway.s2s', target_mfid="mf201", scenario_id="101")
butler.load_matrix('trips.hbm.peak.train.access.transit', target_mfid="mf202", scenario_id="101")
butler.load_matrix('trips.hbm.peak.train.egress.transit', target_mfid="mf203", scenario_id="101")
butler.load_matrix('trips.hbm.peak.subway.access.transit', target_mfid="mf204", scenario_id="101")
butler.load_matrix('trips.hbm.peak.subway.egress.transit', target_mfid="mf205", scenario_id="101")
butler.load_matrix('trips.hbm.peak.express_bus', target_mfid="mf206", scenario_id="101")
butler.load_matrix('trips.hbm.peak.drive_to_and_from', target_mfid="mf207", scenario_id="101")
butler.load_matrix('trips.hbm.peak.train.transfer.s2s', target_mfid="mf208", scenario_id="101")
butler.load_matrix('trips.hbm.peak.train.transfer.ztsa', target_mfid="mf209", scenario_id="101")
butler.load_matrix('trips.hbm.peak.train.access.walk', target_mfid="mf210", scenario_id="101")
butler.load_matrix('trips.hbm.peak.train.egress.walk', target_mfid="mf211", scenario_id="101")
butler.load_matrix('trips.hbm.peak.subway.access.walk', target_mfid="mf212", scenario_id="101")
butler.load_matrix('trips.hbm.peak.subway.egress.walk', target_mfid="mf213", scenario_id="101")
butler.load_matrix('trips.hbm.peak.express_bus.walk', target_mfid="mf214", scenario_id="101")
butler.load_matrix('trips.hbm.peak.express_bus.drive', target_mfid="mf215", scenario_id="101")
butler.load_matrix('trips.hbm.peak.local_bus.walk', target_mfid="mf216", scenario_id="101")
butler.load_matrix('trips.hbm.peak.local_bus.drive', target_mfid="mf217", scenario_id="101")
butler.load_matrix('trips.hbm.peak.rapid_bus.walk', target_mfid="mf218", scenario_id="101")
butler.load_matrix('trips.hbm.peak.rapid_bus.drive', target_mfid="mf219", scenario_id="101")
butler.load_matrix('trips.hbs.peak.train.s2s', target_mfid="mf220", scenario_id="101")
butler.load_matrix('trips.hbs.peak.subway.s2s', target_mfid="mf221", scenario_id="101")
butler.load_matrix('trips.hbs.peak.train.access.transit', target_mfid="mf222", scenario_id="101")
butler.load_matrix('trips.hbs.peak.train.egress.transit', target_mfid="mf223", scenario_id="101")
butler.load_matrix('trips.hbs.peak.subway.access.transit', target_mfid="mf224", scenario_id="101")
butler.load_matrix('trips.hbs.peak.subway.egress.transit', target_mfid="mf225", scenario_id="101")
butler.load_matrix('trips.hbs.peak.express_bus', target_mfid="mf226", scenario_id="101")
butler.load_matrix('trips.hbs.peak.drive_to_and_from', target_mfid="mf227", scenario_id="101")
butler.load_matrix('trips.hbs.peak.train.transfer.s2s', target_mfid="mf228", scenario_id="101")
butler.load_matrix('trips.hbs.peak.train.transfer.ztsa', target_mfid="mf229", scenario_id="101")
butler.load_matrix('trips.hbs.peak.train.access.walk', target_mfid="mf230", scenario_id="101")
butler.load_matrix('trips.hbs.peak.train.egress.walk', target_mfid="mf231", scenario_id="101")
butler.load_matrix('trips.hbs.peak.subway.access.walk', target_mfid="mf232", scenario_id="101")
butler.load_matrix('trips.hbs.peak.subway.egress.walk', target_mfid="mf233", scenario_id="101")
butler.load_matrix('trips.hbs.peak.express_bus.walk', target_mfid="mf234", scenario_id="101")
butler.load_matrix('trips.hbs.peak.express_bus.drive', target_mfid="mf235", scenario_id="101")
butler.load_matrix('trips.hbs.peak.local_bus.walk', target_mfid="mf236", scenario_id="101")
butler.load_matrix('trips.hbs.peak.local_bus.drive', target_mfid="mf237", scenario_id="101")
butler.load_matrix('trips.hbs.peak.rapid_bus.walk', target_mfid="mf238", scenario_id="101")
butler.load_matrix('trips.hbs.peak.rapid_bus.drive', target_mfid="mf239", scenario_id="101")
butler.load_matrix('trips.wbo.peak.train.s2s', target_mfid="mf240", scenario_id="101")
butler.load_matrix('trips.wbo.peak.subway.s2s', target_mfid="mf241", scenario_id="101")
butler.load_matrix('trips.wbo.peak.train.access.transit', target_mfid="mf242", scenario_id="101")
butler.load_matrix('trips.wbo.peak.train.egress.transit', target_mfid="mf243", scenario_id="101")
butler.load_matrix('trips.wbo.peak.subway.access.transit', target_mfid="mf244", scenario_id="101")
butler.load_matrix('trips.wbo.peak.subway.egress.transit', target_mfid="mf245", scenario_id="101")
butler.load_matrix('trips.wbo.peak.express_bus', target_mfid="mf246", scenario_id="101")
butler.load_matrix('trips.wbo.peak.drive_to_and_from', target_mfid="mf247", scenario_id="101")
butler.load_matrix('trips.wbo.peak.train.transfer.s2s', target_mfid="mf248", scenario_id="101")
butler.load_matrix('trips.wbo.peak.train.transfer.ztsa', target_mfid="mf249", scenario_id="101")
butler.load_matrix('trips.wbo.peak.train.access.walk', target_mfid="mf250", scenario_id="101")
butler.load_matrix('trips.wbo.peak.train.egress.walk', target_mfid="mf251", scenario_id="101")
butler.load_matrix('trips.wbo.peak.subway.access.walk', target_mfid="mf252", scenario_id="101")
butler.load_matrix('trips.wbo.peak.subway.egress.walk', target_mfid="mf253", scenario_id="101")
butler.load_matrix('trips.wbo.peak.express_bus.walk', target_mfid="mf254", scenario_id="101")
butler.load_matrix('trips.wbo.peak.express_bus.drive', target_mfid="mf255", scenario_id="101")
butler.load_matrix('trips.wbo.peak.local_bus.walk', target_mfid="mf256", scenario_id="101")
butler.load_matrix('trips.wbo.peak.local_bus.drive', target_mfid="mf257", scenario_id="101")
butler.load_matrix('trips.wbo.peak.rapid_bus.walk', target_mfid="mf258", scenario_id="101")
butler.load_matrix('trips.wbo.peak.rapid_bus.drive', target_mfid="mf259", scenario_id="101")
butler.load_matrix('trips.nhb.peak.train.s2s', target_mfid="mf260", scenario_id="101")
butler.load_matrix('trips.nhb.peak.subway.s2s', target_mfid="mf261", scenario_id="101")
butler.load_matrix('trips.nhb.peak.train.access.transit', target_mfid="mf262", scenario_id="101")
butler.load_matrix('trips.nhb.peak.train.egress.transit', target_mfid="mf263", scenario_id="101")
butler.load_matrix('trips.nhb.peak.subway.access.transit', target_mfid="mf264", scenario_id="101")
butler.load_matrix('trips.nhb.peak.subway.egress.transit', target_mfid="mf265", scenario_id="101")
butler.load_matrix('trips.nhb.peak.express_bus', target_mfid="mf266", scenario_id="101")
butler.load_matrix('trips.nhb.peak.drive_to_and_from', target_mfid="mf267", scenario_id="101")
butler.load_matrix('trips.nhb.peak.train.transfer.s2s', target_mfid="mf268", scenario_id="101")
butler.load_matrix('trips.nhb.peak.train.transfer.ztsa', target_mfid="mf269", scenario_id="101")
butler.load_matrix('trips.nhb.peak.train.access.walk', target_mfid="mf270", scenario_id="101")
butler.load_matrix('trips.nhb.peak.train.egress.walk', target_mfid="mf271", scenario_id="101")
butler.load_matrix('trips.nhb.peak.subway.access.walk', target_mfid="mf272", scenario_id="101")
butler.load_matrix('trips.nhb.peak.subway.egress.walk', target_mfid="mf273", scenario_id="101")
butler.load_matrix('trips.nhb.peak.express_bus.walk', target_mfid="mf274", scenario_id="101")
butler.load_matrix('trips.nhb.peak.express_bus.drive', target_mfid="mf275", scenario_id="101")
butler.load_matrix('trips.nhb.peak.local_bus.walk', target_mfid="mf276", scenario_id="101")
butler.load_matrix('trips.nhb.peak.local_bus.drive', target_mfid="mf277", scenario_id="101")
butler.load_matrix('trips.nhb.peak.rapid_bus.walk', target_mfid="mf278", scenario_id="101")
butler.load_matrix('trips.nhb.peak.rapid_bus.drive', target_mfid="mf279", scenario_id="101")
butler.load_matrix('skim.am_peak.auto.sov.time', target_mfid="mf40", scenario_id="101")

print "Matrices loaded"
# Out:
# Matrices loaded

# %% [markdown]
# ###Compute / save O-D matrices for GO Train and Subway and delete individual matrices

# %%
#Create matrices for peak person trips total calculations

#Define matrix list
ext_mat_list=[[1,'mf120','trips.peak.train.s2s',"mf120","mf140+mf160+mf180+mf200+mf220+mf240+mf260"],
                [2,'mf121','trips.peak.subway.s2s',"mf121","mf141+mf161+mf181+mf201+mf221+mf241+mf261"],
                [3,'mf122','trips.peak.train.access.transit',"mf122","mf142+mf162+mf182+mf202+mf222+mf242+mf262"],
                [4,'mf123','trips.peak.train.egress.transit',"mf123","mf143+mf163+mf183+mf203+mf223+mf243+mf263"],
                [5,'mf124','trips.peak.subway.access.transit',"mf124","mf144+mf164+mf184+mf204+mf224+mf244+mf264"],
                [6,'mf125','trips.peak.subway.egress.transit',"mf125","mf145+mf165+mf185+mf205+mf225+mf245+mf265"],
                [7,'mf126','trips.peak.express_bus',"mf126","mf146+mf166+mf186+mf206+mf226+mf246+mf266"],
                [8,'mf127','trips.peak.drive_to_and_from',"mf127","mf147+mf167+mf187+mf207+mf227+mf247+mf267"],
                [9,'mf128','trips.peak.train.transfer.s2s',"mf128","mf148+mf168+mf188+mf208+mf228+mf248+mf268"],
                [10,'mf129','trips.peak.train.transfer.ztsa',"mf129","mf149+mf169+mf189+mf209+mf229+mf249+mf269"],
                [11,'mf130','trips.peak.train.access.walk',"mf130","mf150+mf170+mf190+mf210+mf230+mf250+mf270"],
                [12,'mf131','trips.peak.train.egress.walk',"mf131","mf151+mf171+mf191+mf211+mf231+mf251+mf271"],
                [13,'mf132','trips.peak.subway.access.walk',"mf132","mf152+mf172+mf192+mf212+mf232+mf252+mf272"],
                [14,'mf133','trips.peak.subway.egress.walk',"mf133","mf153+mf173+mf193+mf213+mf233+mf253+mf273"],
                [15,'mf134','trips.peak.express_bus.walk',"mf134","mf154+mf174+mf194+mf214+mf234+mf254+mf274"],
                [16,'mf135','trips.peak.express_bus.drive',"mf135","mf155+mf175+mf195+mf215+mf235+mf255+mf275"],
                [17,'mf136','trips.peak.local_bus.walk',"mf136","mf156+mf176+mf196+mf216+mf236+mf256+mf276"],
                [18,'mf137','trips.peak.local_bus.drive',"mf137","mf157+mf177+mf197+mf217+mf237+mf257+mf277"],
                [19,'mf138','trips.peak.rapid_bus.walk',"mf138","mf158+mf178+mf198+mf218+mf238+mf258+mf278"],
                [20,'mf139','trips.peak.rapid_bus.drive',"mf139","mf159+mf179+mf199+mf219+mf239+mf259+mf279"],
                [21,'mf40','skim.am_peak.auto.sov.time',"mf40","mf40"]]
                

#Create matrices and compute totals
for mat in ext_mat_list:
    
    if eb.matrix(mat[1]) is None: #Check if the matrix exists; if not, create it
        NAMESPACE = "inro.emme.data.matrix.create_matrix"
        create_matrix = mm.tool(NAMESPACE)
        new_mat = create_matrix(matrix_id=mat[1],
                        matrix_name=mat[2],
                        matrix_description=mat[2],
                        default_value=0)
        NAMESPACE2 = "inro.emme.matrix_calculation.matrix_calculator"
        compute_matrix = mm.tool(NAMESPACE2)
        specification = {
    "type": "MATRIX_CALCULATION",
    "result": mat[3],
    "expression": mat[4],
    "constraint": {
		"by_zone": None,
		"by_value": None,
	}
}
        report = compute_matrix(specification)

    else:
        matrix = eb.matrix(mat[1])
        matrix.name = mat[2] #update matrix name
        matrix.description = mat[2] #update matrix description
        
        NAMESPACE2 = "inro.emme.matrix_calculation.matrix_calculator"
        compute_matrix = mm.tool(NAMESPACE2)
        specification = {
    "type": "MATRIX_CALCULATION",
    "result": mat[3],
    "expression": mat[4],
    "constraint": {
		"by_zone": None,
		"by_value": None,
	}
}
        report = compute_matrix(specification)
        
print "Skim inputs calculated"
# Out:
# Total peak person trips by trip purpose calculated

# %%
#Delete matrices

#Define matrix list to be deleted
ext_mat_list=[[1,"mf140"],
                [2,"mf141"],
                [3,"mf142"],
                [4,"mf143"],
                [5,"mf144"],
                [6,"mf145"],
                [7,"mf146"],
                [8,"mf147"],
                [9,"mf148"],
                [10,"mf149"],
                [11,"mf150"],
                [12,"mf151"],
                [13,"mf152"],
                [14,"mf153"],
                [15,"mf154"],
                [16,"mf155"],
                [17,"mf156"],
                [18,"mf157"],
                [19,"mf158"],
                [20,"mf159"],
                [21,"mf160"],
                [22,"mf161"],
                [23,"mf162"],
                [24,"mf163"],
                [25,"mf164"],
                [26,"mf165"],
                [27,"mf166"],
                [28,"mf167"],
                [29,"mf168"],
                [30,"mf169"],
                [31,"mf170"],
                [32,"mf171"],
                [33,"mf172"],
                [34,"mf173"],
                [35,"mf174"],
                [36,"mf175"],
                [37,"mf176"],
                [38,"mf177"],
                [39,"mf178"],
                [40,"mf179"],
                [41,"mf180"],
                [42,"mf181"],
                [43,"mf182"],
                [44,"mf183"],
                [45,"mf184"],
                [46,"mf185"],
                [47,"mf186"],
                [48,"mf187"],
                [49,"mf188"],
                [50,"mf189"],
                [51,"mf190"],
                [52,"mf191"],
                [53,"mf192"],
                [54,"mf193"],
                [55,"mf194"],
                [56,"mf195"],
                [57,"mf196"],
                [58,"mf197"],
                [59,"mf198"],
                [60,"mf199"],
                [61,"mf200"],
                [62,"mf201"],
                [63,"mf202"],
                [64,"mf203"],
                [65,"mf204"],
                [66,"mf205"],
                [67,"mf206"],
                [68,"mf207"],
                [69,"mf208"],
                [70,"mf209"],
                [71,"mf210"],
                [72,"mf211"],
                [73,"mf212"],
                [74,"mf213"],
                [75,"mf214"],
                [76,"mf215"],
                [77,"mf216"],
                [78,"mf217"],
                [79,"mf218"],
                [80,"mf219"],
                [81,"mf220"],
                [82,"mf221"],
                [83,"mf222"],
                [84,"mf223"],
                [85,"mf224"],
                [86,"mf225"],
                [87,"mf226"],
                [88,"mf227"],
                [89,"mf228"],
                [90,"mf229"],
                [91,"mf230"],
                [92,"mf231"],
                [93,"mf232"],
                [94,"mf233"],
                [95,"mf234"],
                [96,"mf235"],
                [97,"mf236"],
                [98,"mf237"],
                [99,"mf238"],
                [100,"mf239"],
                [101,"mf240"],
                [102,"mf241"],
                [103,"mf242"],
                [104,"mf243"],
                [105,"mf244"],
                [106,"mf245"],
                [107,"mf246"],
                [108,"mf247"],
                [109,"mf248"],
                [110,"mf249"],
                [111,"mf250"],
                [112,"mf251"],
                [113,"mf252"],
                [114,"mf253"],
                [115,"mf254"],
                [116,"mf255"],
                [117,"mf256"],
                [118,"mf257"],
                [119,"mf258"],
                [120,"mf259"],
                [121,"mf260"],
                [122,"mf261"],
                [123,"mf262"],
                [124,"mf263"],
                [125,"mf264"],
                [126,"mf265"],
                [127,"mf266"],
                [128,"mf267"],
                [129,"mf268"],
                [130,"mf269"],
                [131,"mf270"],
                [132,"mf271"],
                [133,"mf272"],
                [134,"mf273"],
                [135,"mf274"],
                [136,"mf275"],
                [137,"mf276"],
                [138,"mf277"],
                [139,"mf278"],
                [140,"mf279"]]
                

#Delete matrices
for mat in ext_mat_list:
    NAMESPACE = "inro.emme.data.matrix.delete_matrix"
    delete_matrix = mm.tool(NAMESPACE)
    del_mat = eb.matrix(mat[1])
    delete_matrix(matrix=del_mat)

print "Individual matrices deleted"
# Out:
# Individual matrices deleted
